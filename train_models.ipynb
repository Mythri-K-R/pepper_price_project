# %%
import pandas as pd
import numpy as np
import os
import pickle
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

#use a 60-day window
WINDOW_SIZE = 60

# Define our directories
MODELS_DIR = "models"
DATA_DIR = "data"

# Ensure the models directory exists
if not os.path.exists(MODELS_DIR):
    os.makedirs(MODELS_DIR)
    print(f"Created directory: {MODELS_DIR}")
else:
    print(f"Directory already exists: {MODELS_DIR}")


# Data Preprocessing Function 
def process_data(file_path, window_size):
    """
    Loads data, scales it, and creates time-series windows (X, y).
    """
    print(f"Loading and processing data from {file_path}...")
    
    try:
        df = pd.read_csv(file_path, parse_dates=['Date'], index_col='Date')
    except Exception as e:
        print(f"Error loading {file_path}: {e}")
        return None, None, None
        
    # Features to use for training
    features = ['Max_Temp', 'Min_Temp', 'Rainfall', 'Price']
    data = df[features]
    
    # Scale the data to [0, 1]
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled_data = scaler.fit_transform(data)
    
    # Create Windows (Sequences)
    X = []
    y = []
    
    for i in range(window_size, len(scaled_data)):
        # X: The previous 'window_size' days of data
        X.append(scaled_data[i-window_size:i])
        
        # y: The 'Price' on the 'i'-th day (index 3)
        y.append(scaled_data[i, 3]) 
        
    X, y = np.array(X), np.array(y)
    
    print(f"Data shape: X={X.shape}, y={y.shape}")
    
    return X, y, scaler

# --- 2. Model Building Function ---
def build_lstm_model(input_shape):
    """
    Defines and compiles the LSTM model architecture.
    """
    model = Sequential()
    
    model.add(LSTM(units=50, return_sequences=True, input_shape=input_shape))
    model.add(Dropout(0.2))

    model.add(LSTM(units=50, return_sequences=False))
    model.add(Dropout(0.2))

    model.add(Dense(units=25))
    model.add(Dense(units=1))

    model.compile(optimizer='adam', loss='mean_squared_error')
    
    return model

print("Helper functions and configuration are ready.")
# Out:
# Directory already exists: models
# Helper functions and configuration are ready.

# %%
# --- 1. SETTINGS FOR MADIKERI ---
model_name = "madikeri"
file_path = os.path.join(DATA_DIR, "madikeri_merged.csv")

print(f"\n--- Training Model for: {model_name.upper()} ---")

# Step 1: Process the data
X_madikeri, y_madikeri, scaler_madikeri = process_data(file_path, WINDOW_SIZE)

if X_madikeri is not None:
    # Step 2: Build the model
    model_madikeri = build_lstm_model(input_shape=(X_madikeri.shape[1], X_madikeri.shape[2]))
    
    # EarlyStopping callback
    early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    # Step 3: Train the model
    print("Starting Madikeri model training...")
    history_madikeri = model_madikeri.fit(
        X_madikeri, 
        y_madikeri,
        epochs=50,
        batch_size=32,
        validation_split=0.1,
        callbacks=[early_stop],
        verbose=1
    )
    
    # Step 4: Save the model and scaler
    model_save_path = os.path.join(MODELS_DIR, f"{model_name}_lstm.h5")
    scaler_save_path = os.path.join(MODELS_DIR, f"{model_name}_scaler.pkl")
    
    model_madikeri.save(model_save_path)
    with open(scaler_save_path, 'wb') as f:
        pickle.dump(scaler_madikeri, f)
        
    print(f"Successfully saved Madikeri model to: {model_save_path}")
    print(f"Successfully saved Madikeri scaler to: {scaler_save_path}")
else:
    print(f"Could not train Madikeri model. Data loading failed.")

print("\n--- Madikeri Training Complete ---")
# Out:
# --- Training Model for: MADIKERI ---
# Loading and processing data from data\madikeri_merged.csv...
# Data shape: X=(3902, 60, 4), y=(3902,)
# C:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Starting Madikeri model training...
# Epoch 1/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 19s 82ms/step - loss: 0.0323 - val_loss: 0.0270
# Epoch 2/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 68ms/step - loss: 0.0083 - val_loss: 0.0260
# Epoch 3/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - loss: 0.0083 - val_loss: 0.0249
# Epoch 4/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - loss: 0.0077 - val_loss: 0.0285
# Epoch 5/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 68ms/step - loss: 0.0073 - val_loss: 0.0223
# Epoch 6/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 69ms/step - loss: 0.0076 - val_loss: 0.0215
# Epoch 7/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 10s 69ms/step - loss: 0.0073 - val_loss: 0.0215
# Epoch 8/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 68ms/step - loss: 0.0068 - val_loss: 0.0198
# Epoch 9/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - loss: 0.0062 - val_loss: 0.0189
# Epoch 10/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 67ms/step - loss: 0.0068 - val_loss: 0.0181
# Epoch 11/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - loss: 0.0060 - val_loss: 0.0169
# Epoch 12/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - loss: 0.0063 - val_loss: 0.0171
# Epoch 13/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 7s 64ms/step - loss: 0.0053 - val_loss: 0.0160
# Epoch 14/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - loss: 0.0053 - val_loss: 0.0154
# Epoch 15/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - loss: 0.0056 - val_loss: 0.0147
# Epoch 16/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 7s 62ms/step - loss: 0.0058 - val_loss: 0.0143
# Epoch 17/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 7s 62ms/step - loss: 0.0055 - val_loss: 0.0136
# Epoch 18/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - loss: 0.0051 - val_loss: 0.0133
# Epoch 19/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 7s 63ms/step - loss: 0.0054 - val_loss: 0.0129
# Epoch 20/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - loss: 0.0056 - val_loss: 0.0125
# Epoch 21/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 10s 59ms/step - loss: 0.0054 - val_loss: 0.0123
# Epoch 22/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - loss: 0.0048 - val_loss: 0.0127
# Epoch 23/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 7s 61ms/step - loss: 0.0056 - val_loss: 0.0122
# Epoch 24/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - loss: 0.0055 - val_loss: 0.0125
# Epoch 25/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - loss: 0.0055 - val_loss: 0.0124
# Epoch 26/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - loss: 0.0046 - val_loss: 0.0120
# Epoch 27/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 10s 56ms/step - loss: 0.0054 - val_loss: 0.0120
# Epoch 28/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - loss: 0.0049 - val_loss: 0.0119
# Epoch 29/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - loss: 0.0056 - val_loss: 0.0118
# Epoch 30/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - loss: 0.0051 - val_loss: 0.0122
# Epoch 31/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 11s 60ms/step - loss: 0.0052 - val_loss: 0.0118
# Epoch 32/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 10s 55ms/step - loss: 0.0049 - val_loss: 0.0119
# Epoch 33/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 7s 61ms/step - loss: 0.0048 - val_loss: 0.0132
# Epoch 34/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - loss: 0.0049 - val_loss: 0.0121
# Epoch 35/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 0.0050 - val_loss: 0.0128
# Epoch 36/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - loss: 0.0059 - val_loss: 0.0122
# Epoch 37/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - loss: 0.0051 - val_loss: 0.0118
# Epoch 38/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 0.0051 - val_loss: 0.0119
# Epoch 39/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - loss: 0.0045 - val_loss: 0.0123
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Successfully saved Madikeri model to: models\madikeri_lstm.h5
# Successfully saved Madikeri scaler to: models\madikeri_scaler.pkl
#
# --- Madikeri Training Complete ---

# %%
# --- 2. SETTINGS FOR SIRSI ---
model_name = "sirsi"
file_path = os.path.join(DATA_DIR, "sirsi_merged.csv")

print(f"\n--- Training Model for: {model_name.upper()} ---")

# Step 1: Process the data
X_sirsi, y_sirsi, scaler_sirsi = process_data(file_path, WINDOW_SIZE)

if X_sirsi is not None:
    # Step 2: Build the model
    model_sirsi = build_lstm_model(input_shape=(X_sirsi.shape[1], X_sirsi.shape[2]))
    
    # EarlyStopping callback
    early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    # Step 3: Train the model
    print("Starting Sirsi model training...")
    history_sirsi = model_sirsi.fit(
        X_sirsi, 
        y_sirsi,
        epochs=50,
        batch_size=32,
        validation_split=0.1,
        callbacks=[early_stop],
        verbose=1
    )
    
    # Step 4: Save the model and scaler
    model_save_path = os.path.join(MODELS_DIR, f"{model_name}_lstm.h5")
    scaler_save_path = os.path.join(MODELS_DIR, f"{model_name}_scaler.pkl")
    
    model_sirsi.save(model_save_path)
    with open(scaler_save_path, 'wb') as f:
        pickle.dump(scaler_sirsi, f)
        
    print(f"Successfully saved Sirsi model to: {model_save_path}")
    print(f"Successfully saved Sirsi scaler to: {scaler_save_path}")
else:
    print(f"Could not train Sirsi model. Data loading failed.")

print("\n--- Sirsi Training Complete ---")
# Out:
# --- Training Model for: SIRSI ---
# Loading and processing data from data\sirsi_merged.csv...
# Data shape: X=(3907, 60, 4), y=(3907,)
# C:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Starting Sirsi model training...
# Epoch 1/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 16s 79ms/step - loss: 0.0301 - val_loss: 0.0019
# Epoch 2/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - loss: 0.0036 - val_loss: 0.0061
# Epoch 3/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - loss: 0.0032 - val_loss: 0.0012
# Epoch 4/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - loss: 0.0027 - val_loss: 0.0017
# Epoch 5/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 7s 64ms/step - loss: 0.0024 - val_loss: 0.0013
# Epoch 6/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 7/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - loss: 0.0021 - val_loss: 0.0012
# Epoch 8/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 7s 64ms/step - loss: 0.0019 - val_loss: 0.0016
# Epoch 9/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 7s 64ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 10/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 7s 63ms/step - loss: 0.0018 - val_loss: 0.0010
# Epoch 11/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 7s 63ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 12/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 7s 63ms/step - loss: 0.0018 - val_loss: 9.1877e-04
# Epoch 13/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 7s 62ms/step - loss: 0.0017 - val_loss: 9.6965e-04
# Epoch 14/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 7s 61ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 15/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 7s 61ms/step - loss: 0.0016 - val_loss: 0.0011
# Epoch 16/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 10s 59ms/step - loss: 0.0015 - val_loss: 0.0010
# Epoch 17/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 18/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 7s 58ms/step - loss: 0.0014 - val_loss: 0.0021
# Epoch 19/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 10s 59ms/step - loss: 0.0014 - val_loss: 8.9087e-04
# Epoch 20/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 7s 58ms/step - loss: 0.0014 - val_loss: 8.6020e-04
# Epoch 21/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - loss: 0.0015 - val_loss: 9.6643e-04
# Epoch 22/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 23/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 10s 58ms/step - loss: 0.0014 - val_loss: 8.6245e-04
# Epoch 24/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - loss: 0.0015 - val_loss: 9.4415e-04
# Epoch 25/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 26/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 27/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 10s 56ms/step - loss: 0.0015 - val_loss: 8.3369e-04
# Epoch 28/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 29/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 30/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - loss: 0.0014 - val_loss: 8.1579e-04
# Epoch 31/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 10s 56ms/step - loss: 0.0014 - val_loss: 8.5246e-04
# Epoch 32/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 10s 56ms/step - loss: 0.0013 - val_loss: 8.4010e-04
# Epoch 33/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 0.0013 - val_loss: 9.4175e-04
# Epoch 34/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 0.0014 - val_loss: 8.5416e-04
# Epoch 35/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 10s 55ms/step - loss: 0.0013 - val_loss: 8.0093e-04
# Epoch 36/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 51ms/step - loss: 0.0014 - val_loss: 8.0943e-04
# Epoch 37/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 11s 54ms/step - loss: 0.0013 - val_loss: 8.2704e-04
# Epoch 38/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 0.0013 - val_loss: 9.3854e-04
# Epoch 39/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - loss: 0.0013 - val_loss: 9.0307e-04
# Epoch 40/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 41/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - loss: 0.0012 - val_loss: 8.5666e-04
# Epoch 42/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 43/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - loss: 0.0012 - val_loss: 7.7270e-04
# Epoch 44/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 45/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 51ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 46/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 51ms/step - loss: 0.0013 - val_loss: 7.8503e-04
# Epoch 47/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - loss: 0.0013 - val_loss: 7.7994e-04
# Epoch 48/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - loss: 0.0012 - val_loss: 8.4010e-04
# Epoch 49/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 50/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 51ms/step - loss: 0.0013 - val_loss: 9.9651e-04
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Successfully saved Sirsi model to: models\sirsi_lstm.h5
# Successfully saved Sirsi scaler to: models\sirsi_scaler.pkl
#
# --- Sirsi Training Complete ---

# %%
# --- 3. SETTINGS FOR CHIKKAMAGALURU ---
model_name = "chikkamagaluru"
file_path = os.path.join(DATA_DIR, "chikkamagaluru_merged.csv")

print(f"\n--- Training Model for: {model_name.upper()} ---")

# Step 1: Process the data
X_chikkamagaluru, y_chikkamagaluru, scaler_chikkamagaluru = process_data(file_path, WINDOW_SIZE)

if X_chikkamagaluru is not None:
    # Step 2: Build the model
    model_chikkamagaluru = build_lgitstm_model(input_shape=(X_chikkamagaluru.shape[1], X_chikkamagaluru.shape[2]))
    
    # EarlyStopping callback
    early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    # Step 3: Train the model
    print("Starting Chikkamagaluru model training...")
    history_chikkamagaluru = model_chikkamagaluru.fit(
        X_chikkamagaluru, 
        y_chikkamagaluru,
        epochs=50,
        batch_size=32,
        validation_split=0.1,
        callbacks=[early_stop],
        verbose=1
    )
    
    # Step 4: Save the model and scaler
    model_save_path = os.path.join(MODELS_DIR, f"{model_name}_lstm.h5")
    scaler_save_path = os.path.join(MODELS_DIR, f"{model_name}_scaler.pkl")
    
    model_chikkamagaluru.save(model_save_path)
    with open(scaler_save_path, 'wb') as f:
        pickle.dump(scaler_chikkamagaluru, f)
        
    print(f"Successfully saved Chikkamagaluru model to: {model_save_path}")
    print(f"Successfully saved Chikkamagaluru scaler to: {scaler_save_path}")
else:
    print(f"Could not train Chikkamagaluru model. Data loading failed.")

print("\n--- Chikkamagaluru Training Complete ---")
# Out:
# --- Training Model for: CHIKKAMAGALURU ---
# Loading and processing data from data\chikkamagaluru_merged.csv...
# Data shape: X=(3901, 60, 4), y=(3901,)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 12
#       8 X_chikkamagaluru, y_chikkamagaluru, scaler_chikkamagaluru = process_data(file_path, WINDOW_SIZE)
#      10 if X_chikkamagaluru is not None:
#      11     # Step 2: Build the model
# ---> 12     model_chikkamagaluru = build_lgitstm_model(input_shape=(X_chikkamagaluru.shape[1], X_chikkamagaluru.shape[2]))
#      14     # EarlyStopping callback
#      15     early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
#
# NameError: name 'build_lgitstm_model' is not defined

# %%
# --- 3. SETTINGS FOR CHIKKAMAGALURU ---
model_name = "chikkamagaluru"
file_path = os.path.join(DATA_DIR, "chikkamagaluru_merged.csv")

print(f"\n--- Training Model for: {model_name.upper()} ---")

# Step 1: Process the data
X_chikkamagaluru, y_chikkamagaluru, scaler_chikkamagaluru = process_data(file_path, WINDOW_SIZE)

if X_chikkamagaluru is not None:
    # Step 2: Build the model
    model_chikkamagaluru = build_lstm_model(input_shape=(X_chikkamagaluru.shape[1], X_chikkamagaluru.shape[2]))    
    # EarlyStopping callback
    early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    # Step 3: Train the model
    print("Starting Chikkamagaluru model training...")
    history_chikkamagaluru = model_chikkamagaluru.fit(
        X_chikkamagaluru, 
        y_chikkamagaluru,
        epochs=50,
        batch_size=32,
        validation_split=0.1,
        callbacks=[early_stop],
        verbose=1
    )
    
    # Step 4: Save the model and scaler
    model_save_path = os.path.join(MODELS_DIR, f"{model_name}_lstm.h5")
    scaler_save_path = os.path.join(MODELS_DIR, f"{model_name}_scaler.pkl")
    
    model_chikkamagaluru.save(model_save_path)
    with open(scaler_save_path, 'wb') as f:
        pickle.dump(scaler_chikkamagaluru, f)
        
    print(f"Successfully saved Chikkamagaluru model to: {model_save_path}")
    print(f"Successfully saved Chikkamagaluru scaler to: {scaler_save_path}")
else:
    print(f"Could not train Chikkamagaluru model. Data loading failed.")

print("\n--- Chikkamagaluru Training Complete ---")
# Out:
# --- Training Model for: CHIKKAMAGALURU ---
# Loading and processing data from data\chikkamagaluru_merged.csv...
# Data shape: X=(3901, 60, 4), y=(3901,)
# C:\Users\hp\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Starting Chikkamagaluru model training...
# Epoch 1/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 16s 79ms/step - loss: 0.0264 - val_loss: 0.0063
# Epoch 2/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - loss: 0.0036 - val_loss: 0.0075
# Epoch 3/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 68ms/step - loss: 0.0038 - val_loss: 0.0066
# Epoch 4/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - loss: 0.0031 - val_loss: 0.0054
# Epoch 5/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - loss: 0.0030 - val_loss: 0.0053
# Epoch 6/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - loss: 0.0031 - val_loss: 0.0054
# Epoch 7/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - loss: 0.0028 - val_loss: 0.0051
# Epoch 8/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - loss: 0.0030 - val_loss: 0.0052
# Epoch 9/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - loss: 0.0026 - val_loss: 0.0049
# Epoch 10/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - loss: 0.0025 - val_loss: 0.0046
# Epoch 11/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 7s 64ms/step - loss: 0.0024 - val_loss: 0.0044
# Epoch 12/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 10s 64ms/step - loss: 0.0024 - val_loss: 0.0052
# Epoch 13/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - loss: 0.0025 - val_loss: 0.0042
# Epoch 14/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 10s 62ms/step - loss: 0.0023 - val_loss: 0.0041
# Epoch 15/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 10s 62ms/step - loss: 0.0024 - val_loss: 0.0042
# Epoch 16/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 10s 61ms/step - loss: 0.0021 - val_loss: 0.0041
# Epoch 17/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - loss: 0.0023 - val_loss: 0.0040
# Epoch 18/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - loss: 0.0021 - val_loss: 0.0039
# Epoch 19/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - loss: 0.0019 - val_loss: 0.0039
# Epoch 20/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - loss: 0.0020 - val_loss: 0.0039
# Epoch 21/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - loss: 0.0021 - val_loss: 0.0037
# Epoch 22/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 7s 58ms/step - loss: 0.0017 - val_loss: 0.0035
# Epoch 23/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - loss: 0.0019 - val_loss: 0.0034
# Epoch 24/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - loss: 0.0018 - val_loss: 0.0033
# Epoch 25/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - loss: 0.0018 - val_loss: 0.0032
# Epoch 26/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - loss: 0.0019 - val_loss: 0.0032
# Epoch 27/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - loss: 0.0016 - val_loss: 0.0032
# Epoch 28/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 0.0018 - val_loss: 0.0032
# Epoch 29/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 11s 57ms/step - loss: 0.0016 - val_loss: 0.0034
# Epoch 30/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - loss: 0.0019 - val_loss: 0.0032
# Epoch 31/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 10s 56ms/step - loss: 0.0017 - val_loss: 0.0032
# Epoch 32/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 10s 57ms/step - loss: 0.0018 - val_loss: 0.0030
# Epoch 33/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - loss: 0.0018 - val_loss: 0.0031
# Epoch 34/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 0.0018 - val_loss: 0.0032
# Epoch 35/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - loss: 0.0016 - val_loss: 0.0031
# Epoch 36/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 12s 112ms/step - loss: 0.0017 - val_loss: 0.0031
# Epoch 37/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 72ms/step - loss: 0.0016 - val_loss: 0.0029
# Epoch 38/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 9s 58ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 39/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 11s 62ms/step - loss: 0.0016 - val_loss: 0.0028
# Epoch 40/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 9s 53ms/step - loss: 0.0016 - val_loss: 0.0031
# Epoch 41/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - loss: 0.0017 - val_loss: 0.0031
# Epoch 42/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 10s 88ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 43/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 10s 86ms/step - loss: 0.0016 - val_loss: 0.0029
# Epoch 44/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 9s 71ms/step - loss: 0.0018 - val_loss: 0.0029
# Epoch 45/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 10s 60ms/step - loss: 0.0018 - val_loss: 0.0030
# Epoch 46/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 47/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 13s 91ms/step - loss: 0.0016 - val_loss: 0.0030
# Epoch 48/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 10s 87ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 49/50
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 8s 61ms/step - loss: 0.0016 - val_loss: 0.0030
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Successfully saved Chikkamagaluru model to: models\chikkamagaluru_lstm.h5
# Successfully saved Chikkamagaluru scaler to: models\chikkamagaluru_scaler.pkl
#
# --- Chikkamagaluru Training Complete ---
